# %%
import zlowfat as z

model = z.SlowFast_Network(clip_shape=[64,224,224,3],num_class=10,alpha=8,beta=1/8,tau=16,method='T_conv')
print(model.summary())
# Out:
# slow_path_input_shape (None, 4, 224, 224, 3)
# fast_path_input_shape (None, 32, 224, 224, 3)
# Model: "slowfast_resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 64, 224, 224 0
# __________________________________________________________________________________________________
# fast_input (Lambda)             (None, 32, 224, 224, 0           input_1[0][0]
# __________________________________________________________________________________________________
# slow_input (Lambda)             (None, 4, 224, 224,  0           input_1[0][0]
# __________________________________________________________________________________________________
# fast_conv1 (Conv3D)             (None, 32, 112, 112, 5888        fast_input[0][0]
# ...
