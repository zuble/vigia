# %%
from utils import globo , rslts
rslts.get_histplot_from_csv(versus=True)
# Out:
# /raid/DATASETS/.zuble/vigia /raid/DATASETS/anomaly
# Processed and updated: /raid/DATASETS/.zuble/vigia/zurgb11/model/hist/1683134074.5709755_relu_sgd_0_2_4000_history.csv
# Processed and updated: /raid/DATASETS/.zuble/vigia/zurgb11/model/hist/1682977827.0801475_relu_sgd_0_2_8000_history.csv
# Processed and updated: /raid/DATASETS/.zuble/vigia/zurgb11/model/hist/1684081055.5799322_mobilenetv2_relu_sgd-0.0002_0_4_4000_history.csv
# Processed and updated: /raid/DATASETS/.zuble/vigia/zurgb11/model/hist/1683929580.7657886_mobilenetv2_fp16_relu_0.0002_sgd_0_4_4000_history.csv
# Processed and updated: /raid/DATASETS/.zuble/vigia/zurgb11/model/hist/1684023392.6864996_xception_fp16_relu_adam-0.0002_0_4_4000_history.csv
# Processed and updated: /raid/DATASETS/.zuble/vigia/zurgb11/model/hist/1684023431.828157_mobilenetv2_relu_adam-0.0002_0_4_4000_history.csv
# 1683134074.5709755_relu_sgd_0_2_4000_history
# 1682977827.0801475_relu_sgd_0_2_8000_history
# ...
